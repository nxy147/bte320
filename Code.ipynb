# %% [markdown]
# <a href="https://colab.research.google.com/github/nxy147/bte320/blob/main/Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=2

# %%
5+3.0
# Out:
# 8.0

# %% [markdown]
# float is with decimals and float is superior to integers in format

# %%
1-2
# Out:
# -1

# %%
2*3
# Out:
# 6

# %%
6/4
# Out:
# 1.5

# %% [markdown]
# division is always a float no matter what

# %%
6//3
# Out:
# 2

# %% [markdown]
# float division is with two dividing signs and will always result in an integer and shows whatever integer is before with no rounding

# %%
6.0//4
# Out:
# 1.0

# %% [markdown]
# if one of the numbers is a float it will still be a float with no decimels besides 0 though

# %%
2**3
# Out:
# 8

# %% [markdown]
# two the power of three with two multiplication

# %%
5 % 3
# Out:
# 2

# %% [markdown]
# the remainder of the division is through percentage signs

# %%
2%3
# Out:
# 2

# %%
3.14* (3**2)
# Out:
# 28.26

# %%
x = 5
2<3
2>3
5<=6
9>=3
x == y
x!=y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1204993280.py in <cell line: 0>()
#       4 5<=6
#       5 9>=3
# ----> 6 x == y
#
# NameError: name 'y' is not defined

# %% [markdown]
# bool results in true or false only
# single equality is assigning something to the variable
# double equality is comparison.
# x == y is equals
# x != y is not equal
# above are the 6 comparison operators in python

# %%
Week 3

# %%
if condition:
  exprs
  exprs
elif another_condition:
  exprs
else
  exprs
# Out:
#   File "/tmp/ipython-input-3241916820.py", line 6
#     else
#         ^
# SyntaxError: expected ':'

# %%
email = "URGENT!! Click www.phis.org to get your reward!"
has_urgent = "URGENT"
has_www = "www."

if has_urgent in email:
  print("phising!")
elif has_www in email:
    print("spam!")
else:
  print("legit!")
# Out:
# phising!

# %%
grade = float(input("Enter numerical grade (0-100): " ))

if grade >=97:
  print("A+")
elif grade >=93:
  print ("A")
# Out:
# Enter numerical grade (0-100): 32
# A-
